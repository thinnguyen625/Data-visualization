# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.random.normal(2,1,100)
y = np.random.normal(3,2,100)

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %%
x = range(100)
y = [2*i + np.random.normal(0, 1, 1) for i in x]

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)
